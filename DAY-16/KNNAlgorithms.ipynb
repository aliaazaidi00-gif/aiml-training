# %% [markdown]
# # KNN Algorithm in Supervised Machine Learning
#     .To decide what something is, look at its nearest neighbors.
# # KNeighborsClassifier of sklearn library for this one.

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
# data collection and splitting the data.
X=np.array([
    [1,3500],
    [2,3200],
    [3,3000],
    [4,2500],
    [5,2300],
    [6,2000],
    [7,2200],
    [2,3700],
])
y=['unfit','unfit','unfit','fit','fit','fit','fit','unfit']

# %%
# create the model
model=KNeighborsClassifier(n_neighbors=3)

# %%
# train the model
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# predict
new_person=[[4.5,2600]]        
pred=model.predict(new_person)
print('Predicted Result:',pred[0])
# Out:
# Predicted Result: fit

# %%
#prediction from taking the values from users
exercise_hours=float(input('Enter Number of Exercise Hours'))
cal_intake=float(input('Enter Number of Calories consumed'))
pred_fu=model.predict([[exercise_hours,cal_intake]])
print(f'Exercise Hours {exercise_hours}, Calories Intake {cal_intake} Your are likely {pred_fu[0]}')
# Out:
# Enter Number of Exercise Hours 3
# Enter Number of Calories consumed 2300
# Exercise Hours 3.0, Calories Intake 2300.0 Your are likely fit

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# collect the data
df=pd.read_csv('fruit_data.csv')
df
# Out:
#    Weight  Size   Fruit
# 0     150   7.0   Apple
# 1     160   7.2   Apple
# 2     200   8.0  Orange
# 3     210   8.2  Orange
# 4     180   7.5       ?

# %%
# split the data
X=df[['Weight','Size']]
y=df['Fruit']

# %%
# model creation
model = KNeighborsClassifier(n_neighbors=3)

# %%
# train the model
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_fruit=pd.DataFrame([[120,2]], columns=['Weight','Size'])
pred=model.predict(new_fruit)
print('Preedicted Result:', pred[0])
# Out:
# Preedicted Result: Apple

# %%
fruit_weight=float(input('Enter Weight of Fruit in gm:'))
fruit_size=float(input('Enter size of fruit in cm:'))
our_fruit=pd.DataFrame([[fruit_weight, fruit_size]], columns=['weight','size'])
pred_fruit=model.predict([[fruit_weight,fruit_size]])
print(f'Fruit Weight is {fruit_weight}, Fruit Size is: {cal_intake} The fruit is likely {pred_fruit[0]}')
# Out:
# Enter Weight of Fruit in gm: 120
# Enter size of fruit in cm: 45
# Fruit Weight is 120.0, Fruit Size is: 2300.0 The fruit is likely Apple

# %%
import pandas as pd

# %% [markdown]
# # EXERCISE
#     - download student_grade.csv from GitHub
#     - Predict a student's grade level (A,B, or C)
#     - Based on hours studied and assignments completed
#     - Using the K-Nearest Neighbors algorithm.

# %%
df=pd.read_csv('student_grade.csv')
df
# Out:
#    Hours_Studied  Assignments_Completed Grade
# 0            1.5                      1     C
# 1            2.0                      2     C
# 2            3.0                      3     B
# 3            4.0                      4     B
# 4            5.0                      5     A
# 5            6.0                      6     A

# %%
X=df[['Hours_Studied','Assignments_Completed']]
y=df['Grade']

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_grade=pd.DataFrame([[120,2]], columns=['Hours_Studied','Assignments_Completed'])
pred=model.predict(new_grade)
print('Predicted Result:', pred[0])
# Out:
# Preedicted Result: A
